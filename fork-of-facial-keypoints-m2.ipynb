# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# !pip install tensorflow==2.0.0-beta1
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# Collecting tensorflow==2.0.0-beta1
#   Downloading https://files.pythonhosted.org/packages/29/6c/2c9a5c4d095c63c2fb37d20def0e4f92685f7aee9243d6aae25862694fd1/tensorflow-2.0.0b1-cp36-cp36m-manylinux1_x86_64.whl (87.9MB)
#      |████████████████████████████████| 87.9MB 33.8MB/s
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.0.0-beta1) (1.22.0)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.0.0-beta1) (1.12.0)
# Requirement already satisfied: protobuf>=3.6.1 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.0.0-beta1) (3.7.1)
# Requirement already satisfied: astor>=0.6.0 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.0.0-beta1) (0.8.0)
# Collecting tb-nightly<1.14.0a20190604,>=1.14.0a20190603 (from tensorflow==2.0.0-beta1)
#   Downloading https://files.pythonhosted.org/packages/a4/96/571b875cd81dda9d5dfa1422a4f9d749e67c0a8d4f4f0b33a4e5f5f35e27/tb_nightly-1.14.0a20190603-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.1MB 18.4MB/s
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.0.0-beta1) (0.33.4)
# Requirement already satisfied: absl-py>=0.7.0 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.0.0-beta1) (0.7.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.0.0-beta1) (1.0.8)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.0.0-beta1) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.0.0-beta1) (1.11.2)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.0.0-beta1) (1.16.4)
# Requirement already satisfied: gast>=0.2.0 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.0.0-beta1) (0.2.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /opt/conda/lib/python3.6/site-packages (from tensorflow==2.0.0-beta1) (0.1.7)
# Collecting tf-estimator-nightly<1.14.0.dev2019060502,>=1.14.0.dev2019060501 (from tensorflow==2.0.0-beta1)
#   Downloading https://files.pythonhosted.org/packages/32/dd/99c47dd007dcf10d63fd895611b063732646f23059c618a373e85019eb0e/tf_estimator_nightly-1.14.0.dev2019060501-py2.py3-none-any.whl (496kB)
#      |████████████████████████████████| 501kB 26.9MB/s
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.6/site-packages (from protobuf>=3.6.1->tensorflow==2.0.0-beta1) (41.0.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/lib/python3.6/site-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow==2.0.0-beta1) (0.15.4)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.6/site-packages (from tb-nightly<1.14.0a20190604,>=1.14.0a20190603->tensorflow==2.0.0-beta1) (3.1.1)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.6/site-packages (from keras-applications>=1.0.6->tensorflow==2.0.0-beta1) (2.9.0)
# ERROR: ethnicolr 0.2.1 has requirement tensorflow==1.12.3, but you'll have tensorflow 2.0.0b1 which is incompatible.
# Installing collected packages: tb-nightly, tf-estimator-nightly, tensorflow
#   Found existing installation: tensorflow 1.14.0
#     Uninstalling tensorflow-1.14.0:
#       Successfully uninstalled tensorflow-1.14.0
# Successfully installed tb-nightly-1.14.0a20190603 tensorflow-2.0.0b1 tf-estimator-nightly-1.14.0.dev2019060501

# %%
tf.executing_eagerly()
# Out:
# True

# %%
import numpy as np
import pandas as pd
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import os
from PIL import Image

# %%
data_dir = '../input/master/P1_Facial_Keypoints-master/data'
training_dir = '../input/master/P1_Facial_Keypoints-master/data/training'
test_dir = '../input/master/P1_Facial_Keypoints-master/data/test'

# %%
label_frame = pd.read_csv(os.path.join(data_dir,'training_frames_keypoints.csv'), index_col='Unnamed: 0')
label_frame.head()
# Out:
#                                0     1     2      3     4      5     6      7  \
# Luis_Fonsi_21.jpg           45.0  98.0  47.0  106.0  49.0  110.0  53.0  119.0
# Lincoln_Chafee_52.jpg       41.0  83.0  43.0   91.0  45.0  100.0  47.0  108.0
# Valerie_Harper_30.jpg       56.0  69.0  56.0   77.0  56.0   86.0  56.0   94.0
# Angelo_Reyes_22.jpg         61.0  80.0  58.0   95.0  58.0  108.0  58.0  120.0
# Kristen_Breitweiser_11.jpg  58.0  94.0  58.0  104.0  60.0  113.0  62.0  121.0
#
#                                8      9  ...     126    127    128    129  \
# Luis_Fonsi_21.jpg           56.0  125.0  ...    83.0  119.0   90.0  117.0
# Lincoln_Chafee_52.jpg       51.0  119.0  ...    85.0  122.0   94.0  120.0
# Valerie_Harper_30.jpg       58.0  103.0  ...    79.0  105.0   86.0  108.0
# Angelo_Reyes_22.jpg         58.0  132.0  ...    98.0  136.0  107.0  139.0
# Kristen_Breitweiser_11.jpg  67.0  130.0  ...    92.0  117.0  103.0  118.0
#
#                              130    131   132    133   134    135
# Luis_Fonsi_21.jpg           83.0  119.0  81.0  122.0  77.0  122.0
# Lincoln_Chafee_52.jpg       85.0  122.0  83.0  122.0  79.0  122.0
# Valerie_Harper_30.jpg       77.0  105.0  75.0  105.0  73.0  105.0
# Angelo_Reyes_22.jpg         95.0  139.0  91.0  139.0  85.0  136.0
# Kristen_Breitweiser_11.jpg  92.0  120.0  88.0  122.0  84.0  122.0
#
# [5 rows x 136 columns]

# %%
test_label_frame = pd.read_csv(os.path.join(data_dir,'test_frames_keypoints.csv'), index_col='Unnamed: 0')
test_label_frame.head()
# Out:
#                                0     1     2      3     4      5     6      7  \
# James_Wolfensohn_00.jpg     25.0  44.0  25.0   49.0  25.0   54.0  25.0   59.0
# Valerie_Harper_30.jpg       55.0  62.0  52.0   72.0  52.0   83.0  55.0   90.0
# Kristen_Breitweiser_11.jpg  60.0  88.0  60.0   98.0  63.0  109.0  65.0  116.0
# Elizabeth_Dole_31.jpg       41.0  96.0  43.0  104.0  47.0  113.0  49.0  120.0
# Kit_Bond_20.jpg             35.0  67.0  37.0   74.0  41.0   81.0  44.0   87.0
#
#                                8      9  ...     126    127    128    129  \
# James_Wolfensohn_00.jpg     26.0   64.0  ...    42.0   65.0   46.0   65.0
# Valerie_Harper_30.jpg       55.0  101.0  ...    78.0  104.0   88.0  106.0
# Kristen_Breitweiser_11.jpg  68.0  127.0  ...    96.0  114.0  106.0  117.0
# Elizabeth_Dole_31.jpg       56.0  128.0  ...    98.0  118.0  103.0  118.0
# Kit_Bond_20.jpg             48.0   96.0  ...    76.0   96.0   83.0   93.0
#
#                              130    131   132    133   134    135
# James_Wolfensohn_00.jpg     42.0   65.0  39.0   65.0  38.0   65.0
# Valerie_Harper_30.jpg       78.0  106.0  75.0  104.0  70.0  104.0
# Kristen_Breitweiser_11.jpg  96.0  117.0  94.0  117.0  89.0  117.0
# Elizabeth_Dole_31.jpg       98.0  120.0  96.0  122.0  94.0  122.0
# Kit_Bond_20.jpg             76.0   98.0  73.0   98.0  69.0   98.0
#
# [5 rows x 136 columns]

# %%
label_frame.shape
# Out:
# (3462, 136)

# %%
test_label_frame.shape
# Out:
# (770, 136)

# %%
def get_img_paths(path):
    file_path = os.listdir(path)
    file_path_full = [os.path.join(training_dir, x) for x in file_path]
    return file_path_full

# %%
training_img_paths = get_img_paths(training_dir)
len(training_img_paths)
# Out:
# 3462

# %%
test_img_paths = get_img_paths(test_dir)
len(test_img_paths)
# Out:
# 2308

# %%
idx = list(test_label_frame.index)
new_paths = []
for x in test_img_paths:
    y = os.path.basename(x)
    if y in idx:
        new_paths.append(x)
test_img_paths = np.array(new_paths)
test_img_paths.shape
# Out:
# (770,)

# %%
def get_labels(data_frame, img_paths=training_img_paths):
    return np.array([data_frame.loc[os.path.basename(x)].values for x in img_paths])

# %%
training_labels = get_labels(label_frame, training_img_paths)
test_labels = get_labels(test_label_frame, test_img_paths)
print(training_labels.shape, test_labels.shape)
print(training_labels[0].shape)
# Out:
# (3462, 136) (770, 136)
# (136,)

# %%
input_size = 128

# %%
def _rotate_data(image, label):
    angle = tf.random.uniform([1,1], minval=-45, maxval=45)
    
    image = Image.fromarray(np.array(tf.squeeze(image)))
    image = Image.Image.rotate(image, angle)
   
    image = tf.convert_to_tensor(np.array(image))
    image = tf.expand_dims(image, -1)
    
    rad = (22*angle)/(7*180)
    cos, sin = tf.math.cos(rad), tf.math.sin(rad)
    rot_mat = np.array([[cos, -sin], [sin, cos]], dtype='float64')
    rot_mat = tf.squeeze(rot_mat)
    
    label = tf.reshape(label, [-1,2])
    
    x0 = input_size/2
    label -= (x0, x0)
    label = tf.matmul(label, rot_mat)
    label += (x0, x0)
    
    label = tf.reshape(label, [-1])
    
    return image, label

# %%
def _preprocess_data(image, label):
    
    mfx = input_size / image.shape[0]
    mfy = input_size / image.shape[1]

    new_label = np.zeros(label.shape)
    new_label[::2] = label[::2] * mfy
    new_label[1::2] = label[1::2] * mfx
    
    image = tf.image.resize(image, [input_size, input_size])
    image = tf.image.rgb_to_grayscale(image)
#     return image, new_label
    return _rotate_data(image, new_label)

# %%
def _load_image(path):
    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image, channels=3)
    return image

# %%
def check_dataset(t=0, img_paths = training_img_paths,labels = training_labels):
    img = _load_image(img_paths[t])
    label = labels[t].copy()

    img, label = _preprocess_data(img, label)
    
    img = tf.squeeze(img)
    label = tf.reshape(label, [-1,2])
    plt.figure()
    plt.imshow(img, cmap='gray')
    plt.scatter(label[:, 0], label[:, 1], s=20, marker='.', c='m')
    plt.show()
    
check_dataset(100)

# %%
check_dataset(0, test_img_paths, test_labels)

# %% [markdown]
# dataset variables
# * training_labels
# * training_img_paths

# %% [markdown]
# # model

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
# !wget 'https://www.kaggleusercontent.com/kf/18179314/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2In0..VrJdpSIa6vTAs7I9oFgTzw.7ZWCApGxmqdxshduMjD2UJYNsp2bQZA8udUbVRW5ZxPhfgIzAlkYwrO32t0TIhofXbpCIfsUp2bcVDpT3Ue8_zylBasUYxoxTzYdg3MqegX7W_IA-CCkbO-gui1I2H2Hh2d5810oe2ryphGZz7_-ZnfOUzMv6Ij1aQ7YSn48PlLFJLegHBPFPU1BuRslOXKg.Dilb0KXoc079yk1LJtc9Pg/model5.h5'
# Out:
# --2019-08-02 17:53:20--  https://www.kaggleusercontent.com/kf/18179314/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2In0..VrJdpSIa6vTAs7I9oFgTzw.7ZWCApGxmqdxshduMjD2UJYNsp2bQZA8udUbVRW5ZxPhfgIzAlkYwrO32t0TIhofXbpCIfsUp2bcVDpT3Ue8_zylBasUYxoxTzYdg3MqegX7W_IA-CCkbO-gui1I2H2Hh2d5810oe2ryphGZz7_-ZnfOUzMv6Ij1aQ7YSn48PlLFJLegHBPFPU1BuRslOXKg.Dilb0KXoc079yk1LJtc9Pg/model5.h5
# Resolving www.kaggleusercontent.com (www.kaggleusercontent.com)... 35.190.26.106
# Connecting to www.kaggleusercontent.com (www.kaggleusercontent.com)|35.190.26.106|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66535584 (63M) [application/octet-stream]
# Saving to: ‘model5.h5’
#
# model5.h5           100%[===================>]  63.45M  95.0MB/s    in 0.7s
#
# 2019-08-02 17:53:21 (95.0 MB/s) - ‘model5.h5’ saved [66535584/66535584]

# %%
model1 = keras.models.load_model('model5.h5')

# %%
model1.summary()
# Out:
# Model: "m1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 64) 18496       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 64, 64)   256         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 128)  73856       batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 256)  295168      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 256)  1024        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 256)  590080      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 512)  1180160     conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 256)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 512)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 256)  1024        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 512)  2048        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 768)  0           batch_normalization_3[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 256)  196864      concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 256)  590080      conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 512)  1180160     conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 64)     0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 512)    0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 8, 8, 64)     256         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 512)    2048        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 576)    0           batch_normalization_1[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 256)    147712      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 512)    1180160     conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 512)    2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512)          0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 136)          69768       dropout[0][0]
# ==================================================================================================
# Total params: 5,531,528
# Trainable params: 5,527,176
# Non-trainable params: 4,352
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model1, 'model1.png')

# %%
model1.compile(optimizer=tf.keras.optimizers.Adam() ,
              loss='mae')

# %%
len(model1.trainable_variables)
# Out:
# 38

# %% [markdown]
# # training
# dataset variables
# * training_labels
# * training_img_paths

# %%
BATCH_SIZE = 1024
steps_per_epoch=tf.math.ceil(BATCH_SIZE/32).numpy()
steps_per_epoch
# Out:
# 32.0

# %%
def train_step(images, labels):
#     print('train step')
    model1.fit(images, labels, epochs=5, verbose=1, batch_size=32)#, steps_per_epoch=steps_per_epoch)

# %%
def train_model(epochs, image_paths = training_img_paths, train_labels = training_labels):
    images = np.zeros((BATCH_SIZE,input_size, input_size,1))
    labels = np.zeros((BATCH_SIZE,train_labels.shape[1]))
    
    for epoch in range(epochs):
        print(epoch+1, end=' ')
        x = tf.random.uniform([BATCH_SIZE], minval=0, maxval=len(image_paths), dtype=tf.dtypes.int32)
        for i in range(BATCH_SIZE):
            image = _load_image(image_paths[x[i]])
            label = train_labels[x[i]].copy()
            images[i], labels[i] = _preprocess_data(image, label)
            
#         print('here')
#         print(images.shape)
        train_step(images, labels)

# %%
train_model(5)
# Out:
# 1 Train on 1024 samples
# Epoch 1/5
# 1024/1024 [==============================] - 431s 421ms/sample - loss: 3.1375
# Epoch 2/5
# 1024/1024 [==============================] - 418s 408ms/sample - loss: 3.0332
# Epoch 3/5
# 1024/1024 [==============================] - 415s 405ms/sample - loss: 2.8885
# Epoch 4/5
# 1024/1024 [==============================] - 413s 403ms/sample - loss: 2.9695
# Epoch 5/5
# 1024/1024 [==============================] - 413s 403ms/sample - loss: 2.8021
# 2 Train on 1024 samples
# Epoch 1/5
# 1024/1024 [==============================] - 412s 402ms/sample - loss: 2.9604
# Epoch 2/5
# 1024/1024 [==============================] - 412s 402ms/sample - loss: 2.9356
# Epoch 3/5
# 1024/1024 [==============================] - 411s 402ms/sample - loss: 2.8789
# Epoch 4/5
# 1024/1024 [==============================] - 411s 401ms/sample - loss: 2.8273
# Epoch 5/5
# 1024/1024 [==============================] - 412s 402ms/sample - loss: 2.8428
# 3 Train on 1024 samples
# Epoch 1/5
# 1024/1024 [==============================] - 411s 401ms/sample - loss: 2.9296
# Epoch 2/5
# 1024/1024 [==============================] - 411s 401ms/sample - loss: 2.8700
# Epoch 3/5
# 1024/1024 [==============================] - 428s 418ms/sample - loss: 2.9951
# Epoch 4/5
# 1024/1024 [==============================] - 442s 432ms/sample - loss: 2.8245
# Epoch 5/5
# 1024/1024 [==============================] - 428s 418ms/sample - loss: 2.8021
# 4 Train on 1024 samples
# Epoch 1/5
# 1024/1024 [==============================] - 420s 410ms/sample - loss: 2.9983
# Epoch 2/5
# 1024/1024 [==============================] - 415s 405ms/sample - loss: 2.8490
# Epoch 3/5
# 1024/1024 [==============================] - 413s 403ms/sample - loss: 2.8369
# Epoch 4/5
# 1024/1024 [==============================] - 410s 401ms/sample - loss: 2.7543
# Epoch 5/5
# 1024/1024 [==============================] - 412s 403ms/sample - loss: 2.7551
# 5 Train on 1024 samples
# Epoch 1/5
# 1024/1024 [==============================] - 413s 403ms/sample - loss: 2.8622
# Epoch 2/5
# 1024/1024 [==============================] - 411s 401ms/sample - loss: 2.8458
# Epoch 3/5
# 1024/1024 [==============================] - 412s 402ms/sample - loss: 2.8732
# Epoch 4/5
# 1024/1024 [==============================] - 413s 403ms/sample - loss: 2.7907
# Epoch 5/5
# 1024/1024 [==============================] - 412s 402ms/sample - loss: 2.8007

# %%
def check_model(t=0):

    img = _load_image(training_img_paths[t])
    label = training_labels[t].copy()

    img, true_label = _preprocess_data(img, label)
    img = tf.reshape(img, [1,input_size, input_size,1])
    label = model1.predict(img).reshape((-1,2))
    
    img = tf.squeeze(img)
    label = tf.reshape(label, [-1,2])
    plt.figure()
    plt.imshow(img, cmap='gray')
    plt.scatter(label[:, 0], label[:, 1], s=20, marker='.', c='m')
    plt.show()

#     true_label = tf.reshape(true_label, [-1,2])
#     plt.figure()
#     plt.imshow(img, cmap='gray')
#     plt.scatter(true_label[:, 0], true_label[:, 1], s=20, marker='.', c='m')
#     plt.show()


for i in [0,10,110,1110,1,11,111,1111]:
    check_model(i)

# %%
model6.save('model6.h5')

# Recreate the exact same model purely from the file:
# model = keras.models.load_model('path_to_my_model.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-a68977ca537a> in <module>
# ----> 1 model6.save('model6.h5')
#       2
#       3 # Recreate the exact same model purely from the file:
#       4 # model = keras.models.load_model('path_to_my_model.h5')
#
# NameError: name 'model6' is not defined

# %%
train_model(5)
# Out:
# 1 Train on 1024 samples
# Epoch 1/5
# 1024/1024 [==============================] - 414s 404ms/sample - loss: 3.0033
# Epoch 2/5
# 1024/1024 [==============================] - 409s 400ms/sample - loss: 2.8952
# Epoch 3/5
# 1024/1024 [==============================] - 408s 399ms/sample - loss: 2.9260
# Epoch 4/5
# 1024/1024 [==============================] - 408s 399ms/sample - loss: 2.8378
# Epoch 5/5
# 1024/1024 [==============================] - 409s 399ms/sample - loss: 2.8980
# 2 Train on 1024 samples
# Epoch 1/5
# 1024/1024 [==============================] - 409s 399ms/sample - loss: 2.9075
# Epoch 2/5
# 1024/1024 [==============================] - 410s 401ms/sample - loss: 2.8078
# Epoch 3/5
# 1024/1024 [==============================] - 412s 402ms/sample - loss: 2.8545
# Epoch 4/5
# 1024/1024 [==============================] - 412s 402ms/sample - loss: 2.7807
# Epoch 5/5
# 1024/1024 [==============================] - 411s 402ms/sample - loss: 2.7727
# 3 Train on 1024 samples
# Epoch 1/5
# 1024/1024 [==============================] - 410s 400ms/sample - loss: 2.8445
# Epoch 2/5
# 1024/1024 [==============================] - 410s 400ms/sample - loss: 2.8091
# Epoch 3/5
# 1024/1024 [==============================] - 409s 399ms/sample - loss: 2.8578
# Epoch 4/5
# 1024/1024 [==============================] - 409s 399ms/sample - loss: 2.8231
# Epoch 5/5
# 1024/1024 [==============================] - 409s 400ms/sample - loss: 2.7849
# 4 Train on 1024 samples
# Epoch 1/5
# 1024/1024 [==============================] - 408s 399ms/sample - loss: 2.8953
# Epoch 2/5
# 1024/1024 [==============================] - 409s 399ms/sample - loss: 2.8437
# Epoch 3/5
# 1024/1024 [==============================] - 409s 400ms/sample - loss: 2.7934
# Epoch 4/5
# 1024/1024 [==============================] - 409s 399ms/sample - loss: 2.7526
# Epoch 5/5
# 1024/1024 [==============================] - 409s 400ms/sample - loss: 2.7870
# 5 Train on 1024 samples
# Epoch 1/5
# 1024/1024 [==============================] - 410s 400ms/sample - loss: 2.9360
# Epoch 2/5
# 1024/1024 [==============================] - 408s 398ms/sample - loss: 2.7790
# Epoch 3/5
# 1024/1024 [==============================] - 409s 399ms/sample - loss: 2.7426
# Epoch 4/5
# 1024/1024 [==============================] - 409s 400ms/sample - loss: 2.8114
# Epoch 5/5
# 1024/1024 [==============================] - 408s 398ms/sample - loss: 2.7428

# %%
def check_model(t=0):

    img = _load_image(training_img_paths[t])
    label = training_labels[t].copy()

    img, true_label = _preprocess_data(img, label)
    img = tf.reshape(img, [1,input_size, input_size,1])
    label = model1.predict(img).reshape((-1,2))
    
    img = tf.squeeze(img)
    label = tf.reshape(label, [-1,2])
    plt.figure()
    plt.imshow(img, cmap='gray')
    plt.scatter(label[:, 0], label[:, 1], s=20, marker='.', c='m')
    plt.show()

#     true_label = tf.reshape(true_label, [-1,2])
#     plt.figure()
#     plt.imshow(img, cmap='gray')
#     plt.scatter(true_label[:, 0], true_label[:, 1], s=20, marker='.', c='m')
#     plt.show()


for i in [0,10,110,1110,1,11,111,1111]:
    check_model(i)

# %%
model1.save('model7.h5')

# Recreate the exact same model purely from the file:
# model = keras.models.load_model('path_to_my_model.h5')

# %%
train_model(5)
# Out:
# 1 Train on 1024 samples
# Epoch 1/5
# 1024/1024 [==============================] - 409s 399ms/sample - loss: 2.9000
# Epoch 2/5
# 1024/1024 [==============================] - 409s 400ms/sample - loss: 2.8028
# Epoch 3/5
# 1024/1024 [==============================] - 408s 399ms/sample - loss: 2.7492
# Epoch 4/5
# 1024/1024 [==============================] - 409s 399ms/sample - loss: 2.6586
# Epoch 5/5
# 1024/1024 [==============================] - 409s 399ms/sample - loss: 2.7750
# 2 Train on 1024 samples
# Epoch 1/5
# 1024/1024 [==============================] - 409s 399ms/sample - loss: 2.8751
# Epoch 2/5
# 1024/1024 [==============================] - 409s 399ms/sample - loss: 2.8177
# Epoch 3/5
# 1024/1024 [==============================] - 408s 399ms/sample - loss: 2.6859
# Epoch 4/5
# 1024/1024 [==============================] - 408s 399ms/sample - loss: 2.7992
# Epoch 5/5
# 1024/1024 [==============================] - 409s 399ms/sample - loss: 2.7386
# 3 Train on 1024 samples
# Epoch 1/5
# 1024/1024 [==============================] - 409s 399ms/sample - loss: 2.8597
# Epoch 2/5
# 1024/1024 [==============================] - 409s 399ms/sample - loss: 2.7863
# Epoch 3/5
# 1024/1024 [==============================] - 413s 404ms/sample - loss: 2.8201
# Epoch 4/5
# 1024/1024 [==============================] - 409s 399ms/sample - loss: 2.7638
# Epoch 5/5
# 1024/1024 [==============================] - 409s 399ms/sample - loss: 2.6661
# 4 Train on 1024 samples
# Epoch 1/5
# 1024/1024 [==============================] - 409s 399ms/sample - loss: 2.8530
# Epoch 2/5
# 1024/1024 [==============================] - 408s 398ms/sample - loss: 2.8105
# Epoch 3/5
# 1024/1024 [==============================] - 409s 400ms/sample - loss: 2.7225
# Epoch 4/5
# 1024/1024 [==============================] - 408s 398ms/sample - loss: 2.6845
# Epoch 5/5
# 1024/1024 [==============================] - 408s 398ms/sample - loss: 2.7009
# 5 Train on 1024 samples
# Epoch 1/5
# 1024/1024 [==============================] - 409s 399ms/sample - loss: 2.7818
# Epoch 2/5
# 1024/1024 [==============================] - 408s 398ms/sample - loss: 2.7285
# Epoch 3/5
# 1024/1024 [==============================] - 407s 398ms/sample - loss: 2.6872
# Epoch 4/5
# 1024/1024 [==============================] - 408s 399ms/sample - loss: 2.6618
# Epoch 5/5
# 1024/1024 [==============================] - 407s 398ms/sample - loss: 2.6896

# %%
def check_model(t=0):

    img = _load_image(training_img_paths[t])
    label = training_labels[t].copy()

    img, true_label = _preprocess_data(img, label)
    img = tf.reshape(img, [1,input_size, input_size,1])
    label = model1.predict(img).reshape((-1,2))
    
    img = tf.squeeze(img)
    label = tf.reshape(label, [-1,2])
    plt.figure()
    plt.imshow(img, cmap='gray')
    plt.scatter(label[:, 0], label[:, 1], s=20, marker='.', c='m')
    plt.show()

#     true_label = tf.reshape(true_label, [-1,2])
#     plt.figure()
#     plt.imshow(img, cmap='gray')
#     plt.scatter(true_label[:, 0], true_label[:, 1], s=20, marker='.', c='m')
#     plt.show()


for i in [0,10,110,1110,1,11,111,1111]:
    check_model(i)

# %%
model1.save('model8.h5')

# Recreate the exact same model purely from the file:
# model = keras.models.load_model('path_to_my_model.h5')
